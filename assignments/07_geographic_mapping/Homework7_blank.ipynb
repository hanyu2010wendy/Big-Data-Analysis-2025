# %% [markdown]
# # Homework 7 Template
#
# Write a short report (about 1,500–2,000 words) and attach your code in an appendix.

# %% [markdown]
# ## Assignment goal
#
# Before running the regression in Homework 4, use data visualization to describe the data as clearly as possible and to gain a stronger understanding of regional patterns.

# %% [markdown]
# **Important note:** The original package included only a blank homework notebook for this task. No solution notebook was included in the uploaded materials.

# %%
from pathlib import Path

def find_project_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "README.md").exists() and (candidate / "data").exists():
            return candidate
    return current

PROJECT_ROOT = find_project_root()
DATA_DIR = PROJECT_ROOT / "data"
ASSETS_DIR = PROJECT_ROOT / "assets"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PROJECT_ROOT

# %%
MODULE_OUTPUT_DIR = OUTPUT_DIR / "homework_07_student"
MODULE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
MODULE_OUTPUT_DIR

# %% [markdown]
# **Optional setup**

# %%
# %pip install -q openpyxl geopandas

# %% [markdown]
# ## You may reuse code and figures from Homework 3 and Homework 4.

# %% [markdown]
# ## Requirement 1. Draw at least one geographic map. (You may draw up to four maps if you want.)

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

panel_df = pd.read_excel(DATA_DIR / "china" / "china_panel_data.xlsx", sheet_name=0)
gdf = gpd.read_file(DATA_DIR / "maps" / "china_provinces.shp")

# TODO: clean the province names, merge the shapefile with your panel data,
# choose a year and one variable, and draw a choropleth map.

# %% [markdown]
# ## Requirement 2. Describe how the selected indicators change across regions during your chosen time period.

# %%
# TODO: create additional line charts, bar charts, or scatter plots to explain regional variation over time.
