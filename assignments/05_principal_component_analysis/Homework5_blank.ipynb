# %% [markdown]
# # Homework 5 Template
#
# Write a report (Word or PDF is fine), and attach your code in an appendix. The original requirement suggests approximately 3,000 words.

# %% [markdown]
# **Important note:** The original package refers to a file named `国家名称与学号.csv`, but that file was not included in the uploaded materials.
#
# I added `data/wdi/country_assignment_template.csv` as a placeholder template so you can decide how to assign countries later.

# %%
from pathlib import Path

def find_project_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "README.md").exists() and (candidate / "data").exists():
            return candidate
    return current

PROJECT_ROOT = find_project_root()
DATA_DIR = PROJECT_ROOT / "data"
ASSETS_DIR = PROJECT_ROOT / "assets"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PROJECT_ROOT

# %%
MODULE_OUTPUT_DIR = OUTPUT_DIR / "homework_05_student"
MODULE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
MODULE_OUTPUT_DIR

# %% [markdown]
# ## Task 1. Filter the data for your assigned country from the World Bank WDI data. (5%)

# %%
import pandas as pd

assignment_df = pd.read_csv(DATA_DIR / "wdi" / "country_assignment_template.csv")
wdi_df = pd.read_csv(DATA_DIR / "wdi" / "WDI_course_subset.csv")

assignment_df.head()

# %% [markdown]
# ## Task 2. Select indicators related to economic development, social progress, and environmental sustainability. (5%)
#
# Try to include different types of indicators, such as population, GDP, energy, education, and health.

# %%
# TODO: select your country and construct a panel dataset with the indicators you want to use for PCA.

# %% [markdown]
# ## Task 3. Conduct a PCA analysis for the assigned country. (35%)
#
# Required elements:
# - Data standardization (10%)
# - KMO and Bartlett's sphericity test (5%)
# - Eigenvalues, variance contribution rates, and cumulative variance contribution rates (20%)

# %%
# TODO: standardize your data, run the PCA, and summarize the retained components.

# %% [markdown]
# ## Task 4. Write a complete analytical report. (55%)
#
# Your report should include:
# - Data description (10%)
# - PCA process (10%)
# - Data visualization (10%)
# - Interpretation of the results (10%)
# - Cross-country comparison (15%)

# %%
# TODO: export any summary tables or figures that you want to include in your report.

# %% [markdown]
# # Bonus
#
# Analyze the reasons behind cross-country differences in the composite index. (10%–20%)
