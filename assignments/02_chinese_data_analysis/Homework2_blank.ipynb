# %% [markdown]
# # Homework 2 Template
#
# Select two regional files (for example Guangxi and Hebei, Hebei and Jilin, or Guangxi and Jilin), organize each file, and merge them into panel data.

# %%
from pathlib import Path

def find_project_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "README.md").exists() and (candidate / "data").exists():
            return candidate
    return current

PROJECT_ROOT = find_project_root()
DATA_DIR = PROJECT_ROOT / "data"
ASSETS_DIR = PROJECT_ROOT / "assets"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PROJECT_ROOT

# %%
# Optional: create an output folder for your work.
MODULE_OUTPUT_DIR = OUTPUT_DIR / "homework_02_student"
MODULE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
MODULE_OUTPUT_DIR

# %% [markdown]
# **Optional setup**

# %%
# %pip install -q xlrd

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Write your own cleaning steps

# %%
# TODO: write your own code to read one province Excel file,
# clean the year columns, add the region name, and reshape the data into panel format.
# You may wrap the steps in a function if you want.

# %% [markdown]
# ## Region 1

# %%
# TODO: choose your first province file from DATA_DIR / "china"
# and create the first province-level panel dataset.

# %% [markdown]
# ## Region 2

# %%
# TODO: choose your second province file from DATA_DIR / "china"
# and create the second province-level panel dataset.

# %% [markdown]
# ## Merge the two province-level panel datasets

# %%
# TODO: concatenate the two province-level panel datasets.
# Then preview the merged result.

# %%
# TODO: check the data types and convert the Year column to integer.

# %%
# TODO: export your final panel dataset to MODULE_OUTPUT_DIR.
