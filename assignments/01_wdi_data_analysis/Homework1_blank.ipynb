# %% [markdown]
# # Homework 1 Template
#
# Complete the tasks below using the WDI data.

# %% [markdown]
# Use the course subset included in this repository for practice. If your assigned country is not included, replace the file with the full WDI dataset.

# %%
from pathlib import Path

def find_project_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "README.md").exists() and (candidate / "data").exists():
            return candidate
    return current

PROJECT_ROOT = find_project_root()
DATA_DIR = PROJECT_ROOT / "data"
ASSETS_DIR = PROJECT_ROOT / "assets"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PROJECT_ROOT
# Out:
# PosixPath('/Users/hanyu/Documents/GitHub/big-data-analysis-2025')

# %%
# Optional: create an output folder for your homework results.
MODULE_OUTPUT_DIR = OUTPUT_DIR / "homework_01_student"
MODULE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
MODULE_OUTPUT_DIR
# Out:
# PosixPath('/Users/hanyu/Documents/GitHub/big-data-analysis-2025/outputs/homework_01_student')

# %% [markdown]
# # Q1. Filter the data for the country you need.

# %%
import pandas as pd

df = pd.read_csv(DATA_DIR / "wdi" / "WDI_course_subset.csv")

country_name = "YOUR_COUNTRY_HERE"

# TODO: filter the dataset for your country.
# df_country = ...

df.head()
# Out:
#   Country Name Country Code  \
# 0      Bahrain          BHR
# 1      Bahrain          BHR
# 2      Bahrain          BHR
# 3      Bahrain          BHR
# 4      Bahrain          BHR
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...   2015   2016   2017   2018   2019  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  100.0  100.0  100.0  100.0  100.0
# 1   NaN   NaN   NaN   NaN   NaN  ...  100.0  100.0  100.0  100.0  100.0
# 2   NaN   NaN   NaN   NaN   NaN  ...  100.0  100.0  100.0  100.0  100.0
# ...

# %% [markdown]
# # Q2. How many rows and columns does the selected country dataset have?

# %%
# TODO: replace with your answer.
# df_country.shape

# %% [markdown]
# # Q3. Reshape the data into panel format.

# %%
# Hint: use melt() and pivot_table().

# panel_data = ...

# panel_data.head()

# %%
# TODO: check the data types and convert the Year column to integer.
# panel_data.dtypes

# %% [markdown]
# # Q4. Export the panel data.

# %%
# TODO: export your panel data.
# panel_data.to_csv(MODULE_OUTPUT_DIR / "Homework1_panel_data.csv", index=False)

# %% [markdown]
# # Q5. How many missing values does each variable have?

# %%
# TODO: count the missing values for each variable.
# isna_data = ...
# isna_data

# %% [markdown]
# # Bonus / Q6. Select the 10 indicators with the fewest missing values and create a compact panel dataset.

# %%
# TODO: create a compact panel dataset with the 10 indicators that have the fewest missing values.
