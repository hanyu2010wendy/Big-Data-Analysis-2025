# %% [markdown]
# # Homework 4 Template
#
# Use the China panel dataset to select variables, visualize the data, and run OLS regressions.

# %%
from pathlib import Path

def find_project_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "README.md").exists() and (candidate / "data").exists():
            return candidate
    return current

PROJECT_ROOT = find_project_root()
DATA_DIR = PROJECT_ROOT / "data"
ASSETS_DIR = PROJECT_ROOT / "assets"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PROJECT_ROOT

# %%
MODULE_OUTPUT_DIR = OUTPUT_DIR / "homework_04_student"
MODULE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
MODULE_OUTPUT_DIR

# %% [markdown]
# **Optional setup**

# %%
# %pip install -q openpyxl seaborn statsmodels

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel(DATA_DIR / "china" / "china_panel_data.xlsx", sheet_name=0)
province_map = pd.read_csv(DATA_DIR / "china" / "province_name_mapping.csv")

df = df.merge(province_map, left_on="地区", right_on="region_cn", how="left")
df.head()

# %% [markdown]
# # Q1. Select regression variables and produce descriptive statistics.

# %%
# Suggested aliases:
# df["year"] = df["年份"]
# df["gdp_per_capita"] = df["国内生产总值（当年价）（亿元）"] / df["总人口（万人）"]
# df["lngdpc"] = np.log(df["gdp_per_capita"])
# df["urbanization_rate"] = df["城镇人口（万人）"] / df["总人口（万人）"] * 100
# df["lnrd_pc"] = np.log(df["R&D经费（万元）"] / df["总人口（万人）"])
# df["digital_finance_index"] = df["数字普惠金融指数"]
# df["ecommerce_share_pct"] = df["有电子商务交易活动企业占总企业数比重（%）"]
# df["lntrade_pc"] = np.log((df["货物出口金额（万美元）"] + df["货物进口金额（万美元）"]) / df["总人口（万人）"])

# Better practice: avoid using variables that are direct components of GDP
# (for example service-sector output) as regressors when lngdpc is the dependent variable.

# TODO: create your variables and display descriptive statistics.

# %% [markdown]
# # Q2. Visualize selected variables.

# %%
# TODO: create at least one scatter plot, line chart, or bar chart.
# Good candidates include urbanization_rate, digital_finance_index,
# ecommerce_share_pct, lnrd_pc, and lngdpc.

# %%
# Optional: classify regions into broader groups (for example coastal vs. non-coastal)
# and compare their digital_finance_index, ecommerce_share_pct, or lngdpc over time.

# %% [markdown]
# # Q3. Run OLS regressions.

# %%
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col

# TODO: define your dependent variable and one or more sets of independent variables.
# A more defensible specification is to explain lngdpc with variables such as
# ecommerce_share_pct, digital_finance_index, urbanization_rate, lnrd_pc,
# or lntrade_pc, rather than direct GDP components.
# Then fit OLS models and export the regression table.
