# %% [markdown]
# # Homework 3 Template
#
# Create figures based on the panel data from Homework 1.

# %% [markdown]
# ## Requirements
#
# - All figures should include x-axis and y-axis labels.
# - Add legends where appropriate.
# - Make the figures visually readable and clean.

# %%
from pathlib import Path

def find_project_root() -> Path:
    current = Path.cwd().resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "README.md").exists() and (candidate / "data").exists():
            return candidate
    return current

PROJECT_ROOT = find_project_root()
DATA_DIR = PROJECT_ROOT / "data"
ASSETS_DIR = PROJECT_ROOT / "assets"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PROJECT_ROOT

# %%
MODULE_OUTPUT_DIR = OUTPUT_DIR / "homework_03_student"
MODULE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
MODULE_OUTPUT_DIR

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(DATA_DIR / "wdi" / "WDI_course_subset.csv")

country_name = "Fiji"  # Replace with your own country if needed.

df_country = df[df["Country Name"] == country_name]

panel_data = df_country.drop(columns="Indicator Code").melt(
    id_vars=["Country Name", "Country Code", "Indicator Name"],
    var_name="Year",
).pivot_table(
    values="value",
    index=["Country Name", "Country Code", "Year"],
    columns="Indicator Name",
).reset_index().rename_axis("", axis=1)

panel_data["Year"] = panel_data["Year"].astype(str).astype(int)
panel_data.head()

# %%
isna_data = panel_data.isna().sum().sort_values(ascending=True)
isna_data

# %% [markdown]
# # Task 1. Create a scatter plot / bubble chart and a bar chart.

# %%
import matplotlib.pyplot as plt

plot_data = panel_data[panel_data["Year"] > 2010]

# TODO: create a scatter plot or bubble chart here.

# %%
# TODO: create a bar chart here.

# %% [markdown]
# # Task 2. Create a line chart using two appropriate variables and export it.

# %%
# TODO: create a two-line chart here.
# plt.savefig(MODULE_OUTPUT_DIR / "Homework3_line_chart.png", bbox_inches="tight")
